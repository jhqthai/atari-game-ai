# %%
from __future__ import print_function
import numpy as np
try:
    import cPickle as pickle
except ImportError:
    import pickle
import tensorflow as tf
# %matplotlib inline

import matplotlib.pyplot as plt
import math

# %%
import sys
if sys.version_info.major > 2:
    xrange = range
del sys

# %%
import gym
env = gym.make('CartPole-v0')
# Out:
# [2018-02-13 17:03:02,880] Making new env: CartPole-v0

# %% [markdown]
# ### Setting Hyper-parameters

# %%
# hyperparameters ?
H = 8 # number of hidden layer neurons
learning_rate = 1e-2
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2 ?
resume = False # resume from previous checkpoint?

model_bs = 3 # Batch size when learning from model
real_bs = 3 # Batch size when learning from real environment

# model initialization
D = 4 # input dimensionality ?

# %% [markdown]
# ### Policy Network

# %%
tf.reset_default_graph() # reset tensorflow graph
observations = tf.placeholder(tf.float32, [None,4], name="input_x")
W1 = tf.get_variable("W1", shape=[4, H], 
                    initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1], 
                    initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score) 

tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32, [None, 1], name="input_y")
advantages = tf.placeholder(tf.float32, name="reward_signal")
adam = tf.train.AdamOptimizer(learning_rate=learning_rate)
W1Grad = tf.placeholder(tf.float32, name="batch_grad1")
W2Grad = tf.placeholder(tf.float32, name="batch_grad2")
batchGrad = [W1Grad,W2Grad]
loglik = tf.log(input_y*(input_y - probability) + (1 - input_y)*(input_y + probability))
loss = -tf.reduce_mean(loglik*advantages)
newGrads = tf.gradients(loss, tvars)
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Model Network
# Implement a multi-layer neural network that predicts the next observation, rewrad, and done state from a current state and action

# %%
mH = 256 # model layer size

input_data = tf.placeholder(tf.float32, [None, 5])
with tf.variable_scope('rnnlm'):
    softmax_w = tf.get_variable("softmax_w", [mH, 50])
    softmax_b = tf.get_variable("softmax_b", [50])
    
previous_state = tf.placeholder(tf.float32, [None,5], name="previous_state")
W1M = tf.get_variable("W1M", shape=[5, mH],
                     initializer=tf.contrib.layers.xavier_initializer())
B1M = tf.Variable(tf.zeros([mH]), name="B1M")
layer1M = tf.nn.relu(tf.matmul(previous_state, W1M) + B1M)
W2M = tf.get_variable("W2M", shape=[mH, mH],
                     initializer=tf.contrib.layers.xavier_initializer())
B2M = tf.Variable(tf.zeros([mH]), name="B2M")
layer2M = tf.nn.relu(tf.matmul(layer1M, W2M) + B2M)
wO = tf.get_variable("wO", shape=[mH, 4],
                    initializer=tf.contrib.layers.xavier_initializer())
wR = tf.get_variable("wR", shape=[mH, 1],
                    initializer=tf.contrib.layers.xavier_initializer())
wD = tf.get_variable("wD", shape=[mH, 1],
                    initializer=tf.contrib.layers.xavier_initializer())

bO = tf.Variable(tf.zeros([4]), name="bO")
bR = tf.Variable(tf.zeros([1]), name="bR")
bD = tf.Variable(tf.zeros([1]), name="bD")

predicted_observation = tf.matmul(layer2M,wO,name="predicted_observation") + bO
predicted_reward = tf.matmul(layer2M, wR, name="predicted_reward") + bR
predicted_done = tf.sigmoid(tf.matmul(layer2M, wD, name="prediced_done") + bD)

true_observation = tf.placeholder(tf.float32, [None, 4], name="true_observation")
true_reward = tf.placeholder(tf.float32, [None,1], name="true_reward")
true_done = tf.placeholder(tf.float32, [None,1], name="true_done")

predicted_state = tf.concat([predicted_observation, predicted_reward, predicted_done], 1)
observation_loss = tf.square(true_observation - predicted_observation)
reward_loss = tf.square(true_reward - predicted_reward)

done_loss = tf.multiply(predicted_done, true_done) + tf.multiply(1-predicted_done, 1-true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss + done_loss + reward_loss)

modelAdam = tf.train.AdamOptimizer(learning_rate=learning_rate)
updateModel = modelAdam.minimize(model_loss)

# %% [markdown]
# ### Helper-functions?

# %%
def resetGradBuffer(gradBuffer):
    for ix, grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    return gradBuffer

def discount_rewards(r):
    """ take 1D float array of rewards and compute discounted reward"""
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(xrange(0, r.size)):
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r

# This function uses our model to produce a new state when given a previous state and action
def stepModel(sess, xs, action):
    toFeed = np.reshape(np.hstack([xs[-1][0],np.array(action)]), [1,5])
    myPredict = sess.run([predicted_state], feed_dict={previous_state: toFeed})
    reward = myPredict[0][:,4]
    observation = myPredict[0][:,0:4]
    observation[:,0] = np.clip(observation[:,0],-2.4,2.4)
    observation[:,2] = np.clip(observation[:,2],-0.4,0.4)
    doneP = np.clip(myPredict[0][:,5],0,1)
    if doneP > 0.1 or len(xs) >= 300:
        done = True
    else:
        done = False
    return observation, reward, done

# %% [markdown]
# ### Training the Policy and Model

# %%
xs, drs, ys, ds = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
real_episodes = 1
init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False
trainTheModel = True
trainThePolicy = False
switch_point = 1

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset()
    x = observation
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= 5000:
        # Start displaying environment once perfomance is acceptably high
        #if ((reward_sum/batch_size > 150) and drawFromModel == False) or rendering == True:
        if (np.all(reward_sum/batch_size > 150) and np.all(drawFromModel == False)) or rendering == True:
            env.render()
            rendering = True
        
        x = np.reshape(observation,[1,4])
        
        tfprob = sess.run(probability, feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0
        
        # record various intermediates (needed)
        xs.append(x)
        y = 1 if action == 0 else 0
        ys.append(y)
        
        # step the model or real environment and get new measurements
        if drawFromModel == False:
            observation, reward, done, info = env.step(action)
        else:
            observation, reward, done = stepModel(sess, xs, action)
            
        reward_sum += reward

        ds.append(done*1)
        drs.append(reward) # record reward ( has to be done after we call step() to get reward for previous action)
            
        if done:
            if drawFromModel == False:
                real_episodes += 1
            episode_number += 1
            
            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            xs,drs,ys,ds = [],[],[],[] # reset array memory
            
            if trainTheModel == True:
                actions = np.array([np.abs(y-1) for y in epy][:-1])
                state_prevs = epx[:-1,:]
                state_prevs = np.hstack([state_prevs,actions])
                state_nexts = epx[1:,:]
                rewards = np.array(epr[1:,:])
                dones = np.array(epd[1:,:])
                state_nextsAll = np.hstack([state_nexts,rewards,dones])
                
                feed_dict={previous_state: state_prevs, true_observation: state_nexts, true_done:dones, true_reward:rewards}
                loss,pState,_ = sess.run([model_loss,predicted_state, updateModel], feed_dict)
            
            if trainThePolicy == True:
                discounted_epr = discount_rewards(epr).astype('float32')
                discounted_epr -= np.mean(discounted_epr)
                discounted_epr /= np.std(discounted_epr)
                tGrad = sess.run(newGrads, feed_dict={observations: epx, 
                                                      input_y: epy, 
                                                      advantages: discounted_epr})
                
                # if gradients become too large, end training process
                if np.sum(tGrad[0] == tGrad[0]) == 0:
                    break
                for ix, grad in enumerate(tGrad):
                    gradBuffer[ix] += grad
                    
            
            if switch_point + batch_size == episode_number:
                switch_point = episode_number
                if trainThePolicy == True:
                    sess.run(updateGrads, feed_dict={W1Grad: gradBuffer[0], W2Grad: gradBuffer[1]})
                    gradBuffer = resetGradBuffer(gradBuffer)
                    
                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                if drawFromModel == False:
                    print ('World Perf: Episode %f. Reward %f. action: %f. mean reward %f.' 
                           % (real_episodes, reward_sum/real_bs, action, running_reward/real_bs))
                    if reward_sum/batch_size > 100:
                        break
                reward_sum = 0
                        
                #once the model has been trained to 100 episodes, we start alternating between trainign the policy
                # from the model and training the model from the real environment.
                if episode_number > 100:
                    drawFromModel = not drawFromModel
                    trainTheModel = not trainTheModel
                    trainThePolicy = not trainThePolicy

            if drawFromModel == True:
                observation = np.random.uniform(-.1, 0.1, [4]) # # Generate reasonable starting point
                batch_size = model_bs
            else:
                observation = env.reset()
                batch_size = real_bs

print(real_episodes)
# Out:
# World Perf: Episode 4.000000. Reward 22.000000. action: 0.000000. mean reward 22.000000.
# World Perf: Episode 7.000000. Reward 28.333333. action: 1.000000. mean reward 22.063333.
# World Perf: Episode 10.000000. Reward 16.000000. action: 0.000000. mean reward 22.002700.
# World Perf: Episode 13.000000. Reward 22.000000. action: 1.000000. mean reward 22.002673.
# World Perf: Episode 16.000000. Reward 20.000000. action: 1.000000. mean reward 21.982646.
# World Perf: Episode 19.000000. Reward 24.000000. action: 1.000000. mean reward 22.002820.
# World Perf: Episode 22.000000. Reward 23.333333. action: 1.000000. mean reward 22.016125.
# World Perf: Episode 25.000000. Reward 20.333333. action: 1.000000. mean reward 21.999297.
# World Perf: Episode 28.000000. Reward 13.000000. action: 1.000000. mean reward 21.909304.
# World Perf: Episode 31.000000. Reward 14.666667. action: 1.000000. mean reward 21.836878.
# World Perf: Episode 34.000000. Reward 34.666667. action: 0.000000. mean reward 21.965176.
# World Perf: Episode 37.000000. Reward 17.666667. action: 1.000000. mean reward 21.922190.
# World Perf: Episode 40.000000. Reward 14.333333. action: 1.000000. mean reward 21.846302.
# World Perf: Episode 43.000000. Reward 18.000000. action: 0.000000. mean reward 21.807839.
# World Perf: Episode 46.000000. Reward 15.000000. action: 1.000000. mean reward 21.739761.
# World Perf: Episode 49.000000. Reward 24.666667. action: 1.000000. mean reward 21.769030.
# World Perf: Episode 52.000000. Reward 18.000000. action: 0.000000. mean reward 21.731339.
# World Perf: Episode 55.000000. Reward 17.333333. action: 1.000000. mean reward 21.687359.
# World Perf: Episode 58.000000. Reward 16.000000. action: 1.000000. mean reward 21.630486.
# World Perf: Episode 61.000000. Reward 16.333333. action: 1.000000. mean reward 21.577514.
# World Perf: Episode 64.000000. Reward 21.000000. action: 1.000000. mean reward 21.571739.
# World Perf: Episode 67.000000. Reward 16.333333. action: 1.000000. mean reward 21.519355.
# World Perf: Episode 70.000000. Reward 19.666667. action: 1.000000. mean reward 21.500828.
# World Perf: Episode 73.000000. Reward 11.333333. action: 1.000000. mean reward 21.399153.
# World Perf: Episode 76.000000. Reward 17.000000. action: 1.000000. mean reward 21.355162.
# World Perf: Episode 79.000000. Reward 25.666667. action: 1.000000. mean reward 21.398277.
# World Perf: Episode 82.000000. Reward 19.666667. action: 0.000000. mean reward 21.380960.
# World Perf: Episode 85.000000. Reward 13.666667. action: 1.000000. mean reward 21.303818.
# World Perf: Episode 88.000000. Reward 11.333333. action: 1.000000. mean reward 21.204113.
# World Perf: Episode 91.000000. Reward 21.666667. action: 0.000000. mean reward 21.208738.
# World Perf: Episode 94.000000. Reward 18.666667. action: 0.000000. mean reward 21.183318.
# World Perf: Episode 97.000000. Reward 21.000000. action: 1.000000. mean reward 21.181484.
# World Perf: Episode 100.000000. Reward 15.666667. action: 0.000000. mean reward 21.126336.
# World Perf: Episode 103.000000. Reward 21.666667. action: 1.000000. mean reward 21.131739.
# World Perf: Episode 106.000000. Reward 22.333333. action: 0.000000. mean reward 20.977100.
# World Perf: Episode 109.000000. Reward 20.333333. action: 1.000000. mean reward 20.962179.
# World Perf: Episode 112.000000. Reward 20.000000. action: 1.000000. mean reward 21.112852.
# World Perf: Episode 115.000000. Reward 28.333333. action: 1.000000. mean reward 21.046129.
# World Perf: Episode 118.000000. Reward 15.666667. action: 1.000000. mean reward 20.840584.
# World Perf: Episode 121.000000. Reward 12.333333. action: 1.000000. mean reward 20.855795.
# World Perf: Episode 124.000000. Reward 15.333333. action: 1.000000. mean reward 20.944130.
# World Perf: Episode 127.000000. Reward 17.666667. action: 1.000000. mean reward 20.768543.
# World Perf: Episode 130.000000. Reward 13.333333. action: 1.000000. mean reward 22.501326.
# World Perf: Episode 133.000000. Reward 19.000000. action: 0.000000. mean reward 22.526276.
# World Perf: Episode 136.000000. Reward 29.666667. action: 1.000000. mean reward 22.692270.
# World Perf: Episode 139.000000. Reward 14.333333. action: 1.000000. mean reward 22.495071.
# World Perf: Episode 142.000000. Reward 15.000000. action: 0.000000. mean reward 22.302576.
# World Perf: Episode 145.000000. Reward 15.666667. action: 0.000000. mean reward 22.162519.
# World Perf: Episode 148.000000. Reward 17.666667. action: 1.000000. mean reward 21.965757.
# World Perf: Episode 151.000000. Reward 17.333333. action: 1.000000. mean reward 21.828613.
# World Perf: Episode 154.000000. Reward 19.333333. action: 1.000000. mean reward 21.770569.
# World Perf: Episode 157.000000. Reward 29.333333. action: 1.000000. mean reward 21.859665.
# World Perf: Episode 160.000000. Reward 22.000000. action: 1.000000. mean reward 22.162001.
# World Perf: Episode 163.000000. Reward 32.000000. action: 1.000000. mean reward 22.369963.
# World Perf: Episode 166.000000. Reward 15.666667. action: 0.000000. mean reward 22.485771.
# World Perf: Episode 169.000000. Reward 21.666667. action: 0.000000. mean reward 22.662828.
# World Perf: Episode 172.000000. Reward 15.333333. action: 1.000000. mean reward 22.576780.
# World Perf: Episode 175.000000. Reward 29.333333. action: 0.000000. mean reward 22.580538.
# World Perf: Episode 178.000000. Reward 14.000000. action: 1.000000. mean reward 22.319635.
# World Perf: Episode 181.000000. Reward 26.666667. action: 1.000000. mean reward 22.184690.
# World Perf: Episode 184.000000. Reward 18.333333. action: 0.000000. mean reward 21.977982.
# World Perf: Episode 187.000000. Reward 33.666667. action: 1.000000. mean reward 22.172478.
# World Perf: Episode 190.000000. Reward 17.333333. action: 1.000000. mean reward 21.992477.
# World Perf: Episode 193.000000. Reward 25.333333. action: 1.000000. mean reward 21.922590.
# World Perf: Episode 196.000000. Reward 19.333333. action: 1.000000. mean reward 21.744619.
# World Perf: Episode 199.000000. Reward 22.666667. action: 1.000000. mean reward 21.686523.
# World Perf: Episode 202.000000. Reward 25.000000. action: 1.000000. mean reward 21.586649.
# World Perf: Episode 205.000000. Reward 33.666667. action: 1.000000. mean reward 21.678850.
# World Perf: Episode 208.000000. Reward 15.666667. action: 1.000000. mean reward 22.337837.
# World Perf: Episode 211.000000. Reward 17.333333. action: 1.000000. mean reward 23.008535.
# World Perf: Episode 214.000000. Reward 32.000000. action: 1.000000. mean reward 22.945526.
# World Perf: Episode 217.000000. Reward 21.666667. action: 0.000000. mean reward 22.803610.
# World Perf: Episode 220.000000. Reward 32.666667. action: 1.000000. mean reward 22.726959.
# World Perf: Episode 223.000000. Reward 25.333333. action: 0.000000. mean reward 22.802977.
# World Perf: Episode 226.000000. Reward 38.333333. action: 1.000000. mean reward 22.940908.
# World Perf: Episode 229.000000. Reward 30.666667. action: 1.000000. mean reward 23.162184.
# World Perf: Episode 232.000000. Reward 19.333333. action: 0.000000. mean reward 24.876356.
# World Perf: Episode 235.000000. Reward 17.333333. action: 0.000000. mean reward 24.955299.
# World Perf: Episode 238.000000. Reward 26.666667. action: 1.000000. mean reward 25.149420.
# World Perf: Episode 241.000000. Reward 49.000000. action: 1.000000. mean reward 25.192909.
# World Perf: Episode 244.000000. Reward 33.000000. action: 0.000000. mean reward 25.156876.
# World Perf: Episode 247.000000. Reward 25.666667. action: 0.000000. mean reward 28.187607.
# World Perf: Episode 250.000000. Reward 26.000000. action: 1.000000. mean reward 30.430679.
# World Perf: Episode 253.000000. Reward 19.666667. action: 1.000000. mean reward 31.379419.
# World Perf: Episode 256.000000. Reward 28.666667. action: 0.000000. mean reward 31.228155.
# World Perf: Episode 259.000000. Reward 31.666667. action: 1.000000. mean reward 31.164949.
# World Perf: Episode 262.000000. Reward 17.666667. action: 0.000000. mean reward 30.841391.
# World Perf: Episode 265.000000. Reward 26.666667. action: 1.000000. mean reward 30.610540.
# World Perf: Episode 268.000000. Reward 38.666667. action: 1.000000. mean reward 30.746401.
# World Perf: Episode 271.000000. Reward 45.000000. action: 1.000000. mean reward 30.783068.
# World Perf: Episode 274.000000. Reward 28.000000. action: 0.000000. mean reward 30.536270.
# World Perf: Episode 277.000000. Reward 30.333333. action: 0.000000. mean reward 30.297247.
# World Perf: Episode 280.000000. Reward 26.333333. action: 1.000000. mean reward 30.637449.
# World Perf: Episode 283.000000. Reward 19.000000. action: 1.000000. mean reward 30.568375.
# World Perf: Episode 286.000000. Reward 19.000000. action: 0.000000. mean reward 30.246367.
# World Perf: Episode 289.000000. Reward 58.000000. action: 0.000000. mean reward 30.309555.
# World Perf: Episode 292.000000. Reward 54.666667. action: 0.000000. mean reward 30.429565.
# World Perf: Episode 295.000000. Reward 31.000000. action: 1.000000. mean reward 30.551374.
# World Perf: Episode 298.000000. Reward 25.666667. action: 0.000000. mean reward 30.486162.
# World Perf: Episode 301.000000. Reward 15.333333. action: 0.000000. mean reward 30.157301.
# World Perf: Episode 304.000000. Reward 50.666667. action: 1.000000. mean reward 30.542967.
# World Perf: Episode 307.000000. Reward 33.333333. action: 0.000000. mean reward 30.660383.
# World Perf: Episode 310.000000. Reward 33.666667. action: 1.000000. mean reward 30.565958.
# World Perf: Episode 313.000000. Reward 20.000000. action: 0.000000. mean reward 30.237783.
# World Perf: Episode 316.000000. Reward 30.333333. action: 0.000000. mean reward 32.509884.
# World Perf: Episode 319.000000. Reward 25.333333. action: 1.000000. mean reward 32.409641.
# World Perf: Episode 322.000000. Reward 26.666667. action: 1.000000. mean reward 32.192696.
# World Perf: Episode 325.000000. Reward 22.000000. action: 1.000000. mean reward 32.556911.
# World Perf: Episode 328.000000. Reward 12.000000. action: 0.000000. mean reward 32.176586.
# World Perf: Episode 331.000000. Reward 27.000000. action: 0.000000. mean reward 31.880934.
# World Perf: Episode 334.000000. Reward 25.666667. action: 1.000000. mean reward 31.922621.
# World Perf: Episode 337.000000. Reward 25.666667. action: 1.000000. mean reward 31.973650.
# World Perf: Episode 340.000000. Reward 36.333333. action: 1.000000. mean reward 31.902901.
# World Perf: Episode 343.000000. Reward 31.333333. action: 0.000000. mean reward 31.710352.
# World Perf: Episode 346.000000. Reward 32.000000. action: 1.000000. mean reward 31.463585.
# World Perf: Episode 349.000000. Reward 32.333333. action: 1.000000. mean reward 33.374283.
# World Perf: Episode 352.000000. Reward 31.666667. action: 0.000000. mean reward 33.149261.
# World Perf: Episode 355.000000. Reward 30.000000. action: 1.000000. mean reward 33.089451.
# World Perf: Episode 358.000000. Reward 19.333333. action: 1.000000. mean reward 32.805908.
# World Perf: Episode 361.000000. Reward 36.666667. action: 1.000000. mean reward 32.723179.
# World Perf: Episode 364.000000. Reward 42.000000. action: 1.000000. mean reward 32.715202.
# World Perf: Episode 367.000000. Reward 40.333333. action: 0.000000. mean reward 32.771149.
# World Perf: Episode 370.000000. Reward 17.000000. action: 1.000000. mean reward 32.836849.
# World Perf: Episode 373.000000. Reward 65.000000. action: 1.000000. mean reward 33.016396.
# World Perf: Episode 376.000000. Reward 34.000000. action: 1.000000. mean reward 32.976780.
# World Perf: Episode 379.000000. Reward 25.666667. action: 0.000000. mean reward 32.797840.
# World Perf: Episode 382.000000. Reward 45.000000. action: 1.000000. mean reward 33.059021.
# World Perf: Episode 385.000000. Reward 24.333333. action: 1.000000. mean reward 35.547779.
# World Perf: Episode 388.000000. Reward 19.000000. action: 0.000000. mean reward 37.848797.
# World Perf: Episode 391.000000. Reward 42.000000. action: 1.000000. mean reward 38.001690.
# World Perf: Episode 394.000000. Reward 26.666667. action: 0.000000. mean reward 37.646427.
# World Perf: Episode 397.000000. Reward 50.000000. action: 0.000000. mean reward 37.675175.
# World Perf: Episode 400.000000. Reward 53.333333. action: 1.000000. mean reward 37.611115.
# World Perf: Episode 403.000000. Reward 34.333333. action: 1.000000. mean reward 37.364262.
# World Perf: Episode 406.000000. Reward 25.666667. action: 1.000000. mean reward 37.433681.
# World Perf: Episode 409.000000. Reward 47.666667. action: 0.000000. mean reward 37.526443.
# World Perf: Episode 412.000000. Reward 44.666667. action: 0.000000. mean reward 37.802677.
# World Perf: Episode 415.000000. Reward 67.333333. action: 0.000000. mean reward 38.896393.
# World Perf: Episode 418.000000. Reward 46.333333. action: 1.000000. mean reward 39.176769.
# World Perf: Episode 421.000000. Reward 41.666667. action: 0.000000. mean reward 39.339611.
# World Perf: Episode 424.000000. Reward 30.333333. action: 0.000000. mean reward 39.057568.
# World Perf: Episode 427.000000. Reward 23.666667. action: 1.000000. mean reward 44.276417.
# World Perf: Episode 430.000000. Reward 31.000000. action: 0.000000. mean reward 43.835102.
# World Perf: Episode 433.000000. Reward 41.000000. action: 1.000000. mean reward 43.513046.
# World Perf: Episode 436.000000. Reward 33.666667. action: 0.000000. mean reward 43.046249.
# /home/john/anaconda2/envs/my_env35/lib/python3.5/site-packages/numpy/core/_methods.py:116: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# World Perf: Episode 439.000000. Reward 75.000000. action: 0.000000. mean reward 31048646745223449280512.000000.
# World Perf: Episode 442.000000. Reward 40.000000. action: 1.000000. mean reward 30430777646146167767040.000000.
# World Perf: Episode 445.000000. Reward 50.333333. action: 0.000000. mean reward 29825205625851421392896.000000.
# World Perf: Episode 448.000000. Reward 37.666667. action: 1.000000. mean reward 40243315089853179232256.000000.
# World Perf: Episode 451.000000. Reward 47.666667. action: 1.000000. mean reward 39442475996914902892544.000000.
# World Perf: Episode 454.000000. Reward 24.333333. action: 0.000000. mean reward 38657570639458263367680.000000.
# World Perf: Episode 457.000000. Reward 31.333333. action: 1.000000. mean reward 37888283765509344722944.000000.
# World Perf: Episode 460.000000. Reward 19.666667. action: 1.000000. mean reward 37134311382093299449856.000000.
# World Perf: Episode 463.000000. Reward 58.000000. action: 0.000000. mean reward 36395338237236211613696.000000.
# World Perf: Episode 466.000000. Reward 35.333333. action: 0.000000. mean reward 35671069345162488446976.000000.
# World Perf: Episode 469.000000. Reward 36.000000. action: 1.000000. mean reward 34961218727295791923200.000000.
# World Perf: Episode 472.000000. Reward 50.666667. action: 0.000000. mean reward 34265491397860529274880.000000.
# World Perf: Episode 475.000000. Reward 42.333333. action: 0.000000. mean reward 33583605881879989846016.000000.
# World Perf: Episode 478.000000. Reward 30.000000. action: 0.000000. mean reward 32915294215176345092096.000000.
# World Perf: Episode 481.000000. Reward 42.000000. action: 0.000000. mean reward 32260277174572698042368.000000.
# World Perf: Episode 484.000000. Reward 20.333333. action: 0.000000. mean reward 31618298054890288578560.000000.
# World Perf: Episode 487.000000. Reward 47.666667. action: 0.000000. mean reward 30989095647350729211904.000000.
# World Perf: Episode 490.000000. Reward 31.333333. action: 0.000000. mean reward 30372413246775259824128.000000.
# World Perf: Episode 493.000000. Reward 40.333333. action: 0.000000. mean reward 29768003155184375037952.000000.
# World Perf: Episode 496.000000. Reward 49.000000. action: 0.000000. mean reward 29175622178198196846592.000000.
# World Perf: Episode 499.000000. Reward 43.333333. action: 1.000000. mean reward 28595027121436847243264.000000.
# World Perf: Episode 502.000000. Reward 47.000000. action: 1.000000. mean reward 28025988301319330332672.000000.
# World Perf: Episode 505.000000. Reward 56.000000. action: 1.000000. mean reward 27468271530665022849024.000000.
# World Perf: Episode 508.000000. Reward 27.000000. action: 1.000000. mean reward 26921651629492556267520.000000.
# World Perf: Episode 511.000000. Reward 58.000000. action: 1.000000. mean reward 26385912425019816804352.000000.
# World Perf: Episode 514.000000. Reward 52.000000. action: 1.000000. mean reward 25860830989065249619968.000000.
# World Perf: Episode 517.000000. Reward 72.333333. action: 1.000000. mean reward 25346202407845809356800.000000.
# World Perf: Episode 520.000000. Reward 52.000000. action: 1.000000. mean reward 24841812760379195916288.000000.
# World Perf: Episode 523.000000. Reward 87.333333. action: 1.000000. mean reward 24347461636481991311360.000000.
# World Perf: Episode 526.000000. Reward 53.000000. action: 0.000000. mean reward 23862946374170963869696.000000.
# World Perf: Episode 529.000000. Reward 56.666667. action: 1.000000. mean reward 23388073318662136659968.000000.
# World Perf: Episode 532.000000. Reward 36.666667. action: 0.000000. mean reward 22922651066971346436096.000000.
# World Perf: Episode 535.000000. Reward 41.333333. action: 0.000000. mean reward 22466492719714057322496.000000.
# World Perf: Episode 538.000000. Reward 60.333333. action: 0.000000. mean reward 22019409125705919758336.000000.
# World Perf: Episode 541.000000. Reward 38.333333. action: 1.000000. mean reward 21581222392761652609024.000000.
# World Perf: Episode 544.000000. Reward 58.666667. action: 1.000000. mean reward 21151756880495788425216.000000.
# World Perf: Episode 547.000000. Reward 45.666667. action: 0.000000. mean reward 20730836948522859757568.000000.
# World Perf: Episode 550.000000. Reward 72.000000. action: 0.000000. mean reward 20318293711856840212480.000000.
# World Perf: Episode 553.000000. Reward 49.666667. action: 0.000000. mean reward 19913960537311517081600.000000.
# World Perf: Episode 556.000000. Reward 47.333333. action: 0.000000. mean reward 19517673043500491341824.000000.
# World Perf: Episode 559.000000. Reward 35.000000. action: 1.000000. mean reward 19129271352636991340544.000000.
# World Perf: Episode 562.000000. Reward 43.333333. action: 0.000000. mean reward 18748598964633965953024.000000.
# World Perf: Episode 565.000000. Reward 54.000000. action: 1.000000. mean reward 18375501631204177739776.000000.
# World Perf: Episode 568.000000. Reward 32.666667. action: 0.000000. mean reward 18009830733559923474432.000000.
# World Perf: Episode 571.000000. Reward 44.666667. action: 0.000000. mean reward 17651435401113686245376.000000.
# World Perf: Episode 574.000000. Reward 53.000000. action: 0.000000. mean reward 17300172644577297039360.000000.
# World Perf: Episode 577.000000. Reward 47.666667. action: 1.000000. mean reward 16955899474662586843136.000000.
# World Perf: Episode 580.000000. Reward 35.333333. action: 0.000000. mean reward 16618477405681014013952.000000.
# World Perf: Episode 583.000000. Reward 41.666667. action: 1.000000. mean reward 16287771329643757436928.000000.
# World Perf: Episode 586.000000. Reward 42.333333. action: 0.000000. mean reward 15963645012662089154560.000000.
# World Perf: Episode 589.000000. Reward 55.000000. action: 0.000000. mean reward 15645968976246722265088.000000.
# World Perf: Episode 592.000000. Reward 76.666667. action: 0.000000. mean reward 15334613741908369866752.000000.
# World Perf: Episode 595.000000. Reward 50.000000. action: 0.000000. mean reward 15029456586557186113536.000000.
# World Perf: Episode 598.000000. Reward 39.666667. action: 1.000000. mean reward 14730370283503697788928.000000.
# World Perf: Episode 601.000000. Reward 40.666667. action: 0.000000. mean reward 14437235487357779574784.000000.
# World Perf: Episode 604.000000. Reward 63.000000. action: 0.000000. mean reward 14149935104529119838208.000000.
# World Perf: Episode 607.000000. Reward 59.333333. action: 1.000000. mean reward 13868352041427406946304.000000.
# World Perf: Episode 610.000000. Reward 35.000000. action: 1.000000. mean reward 13592371456262142951424.000000.
# World Perf: Episode 613.000000. Reward 61.000000. action: 0.000000. mean reward 13321883010842457276416.000000.
# World Perf: Episode 616.000000. Reward 62.333333. action: 0.000000. mean reward 13056778618777293029376.000000.
# World Perf: Episode 619.000000. Reward 70.000000. action: 1.000000. mean reward 12796947941875779633152.000000.
# World Perf: Episode 622.000000. Reward 37.666667. action: 1.000000. mean reward 12542288523246394408960.000000.
# World Perf: Episode 625.000000. Reward 41.000000. action: 1.000000. mean reward 12292696780097707835392.000000.
# World Perf: Episode 628.000000. Reward 54.666667. action: 0.000000. mean reward 12048072507338010918912.000000.
# World Perf: Episode 631.000000. Reward 43.666667. action: 0.000000. mean reward 11808316625775501508608.000000.
# World Perf: Episode 634.000000. Reward 55.333333. action: 0.000000. mean reward 11573331182118284296192.000000.
# World Perf: Episode 637.000000. Reward 103.666667. action: 0.000000. mean reward 11343021600774184501248.000000.
# 637

# %%
plt.figure(figsize=(8, 12))
for i in range(6):
    plt.subplot(6, 2, 2*i + 1)
    plt.plot(pState[:,i])
    plt.subplot(6,2,2*i+1)
    plt.plot(state_nextsAll[:,i])
plt.tight_layout()
# Out:
# /home/john/anaconda2/envs/my_env35/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
